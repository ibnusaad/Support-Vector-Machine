# 95      Laki-Laki             Ya                 Ya  Menengah           3.88
# 96      Perempuan             Ya                 Ya  Menengah           3.88
# 97      Perempuan             Ya                 Ya      Muda           4.00
# 98      Laki-Laki             Ya                 Ya  Menengah           3.63
# 99      Perempuan             Ya                 Ya  Menengah           3.75
# 100     Laki-Laki             Ya                 Ya  Menengah           3.88
# 101     Laki-Laki             Ya              Tidak  Menengah           3.88
# 102     Laki-Laki             Ya                 Ya  Menengah           3.88
# 103     Perempuan             Ya                 Ya  Menengah           3.88
# 104     Perempuan             Ya                 Ya      Muda           3.88
# 105     Laki-Laki             Ya                 Ya  Menengah           4.00
# 106     Laki-Laki             Ya                 Ya      Muda           4.00
# 107     Laki-Laki             Ya                 Ya  Menengah           0.00
# 108     Laki-Laki             Ya                 Ya  Menengah           3.00
# 109     Perempuan             Ya                 Ya  Menengah           0.00
#
#     Ujian Komprehensif Progres Disertasi Publikasi   Class
# 0                Tidak             Tidak     Tidak      DO
# 1                   Ya           Selesai     Sudah  NON DO
# 2                   Ya             Tidak     Tidak      DO
# 3                   Ya             Tidak     Tidak      DO
# 4                   Ya             Tidak     Tidak      DO
# 5                   Ya           Selesai     Sudah  NON DO
# 6                   Ya           Selesai     Sudah  NON DO
# 7                   Ya           Selesai     Sudah  NON DO
# 8                   Ya           Selesai     Sudah  NON DO
# 9                   Ya           Selesai     Sudah  NON DO
# 10                  Ya           Selesai     Sudah  NON DO
# 11                  Ya             Tidak     Tidak      DO
# 12                  Ya             Tidak     Tidak      DO
# 13                  Ya             Tidak     Tidak      DO
# 14                  Ya             Tidak     Tidak      DO
# 15                  Ya             Tidak     Tidak      DO
# 16                  Ya           Selesai     Sudah  NON DO
# 17                  Ya           Selesai     Sudah  NON DO
# 18                  Ya           Selesai     Sudah  NON DO
# 19                  Ya           Selesai     Sudah  NON DO
# 20                  Ya           Selesai     Sudah  NON DO
# 21                  Ya             Tidak     Tidak      DO
# 22                  Ya           Selesai     Sudah  NON DO
# 23                  Ya             Tidak     Tidak      DO
# 24                  Ya           Selesai     Sudah  NON DO
# 25                  Ya           Selesai     Sudah  NON DO
# 26                  Ya           Selesai     Sudah  NON DO
# 27                  Ya           Selesai     Sudah  NON DO
# 28                  Ya             Tidak     Tidak      DO
# 29                  Ya           Selesai     Sudah  NON DO
# 30                  Ya           Selesai     Sudah  NON DO
# 31                  Ya           Selesai     Sudah  NON DO
# 32                  Ya           Selesai     Sudah  NON DO
# 33                  Ya             Tidak     Tidak      DO
# 34                  Ya             Tidak     Tidak      DO
# 35                  Ya             Tidak     Tidak      DO
# 36                  Ya             Tidak     Tidak      DO
# 37                  Ya             Tidak     Tidak      DO
# 38                  Ya           Selesai     Sudah  NON DO
# 39                  Ya           Selesai     Sudah  NON DO
# 40                  Ya           Selesai     Sudah  NON DO
# 41                  Ya             Tidak     Tidak      DO
# 42                  Ya             Tidak     Tidak      DO
# 43                  Ya             Tidak     Tidak      DO
# 44                  Ya           Selesai     Sudah  NON DO
# 45                  Ya             Tidak     Tidak      DO
# 46                  Ya             Tidak     Tidak      DO
# 47                  Ya           Selesai     Sudah  NON DO
# 48                  Ya           Selesai     Sudah  NON DO
# 49                  Ya             Tidak     Tidak      DO
# 50                  Ya             Tidak     Tidak      DO
# 51                  Ya             Tidak     Tidak      DO
# 52                  Ya           Selesai     Sudah  NON DO
# 53                  Ya           Selesai     Sudah  NON DO
# 54                  Ya           Selesai     Sudah  NON DO
# 55                  Ya             Tidak     Tidak      DO
# 56                  Ya           Selesai     Sudah  NON DO
# 57                  Ya             Tidak     Tidak      DO
# 58                  Ya             Tidak     Tidak      DO
# 59                  Ya             Tidak     Tidak      DO
# 60                  Ya             Tidak     Tidak      DO
# 61                  Ya           Selesai     Sudah  NON DO
# 62                  Ya           Selesai     Sudah  NON DO
# 63                  Ya           Selesai     Sudah      DO
# 64                  Ya           Selesai     Sudah      DO
# 65                  Ya           Selesai     Sudah      DO
# 66                  Ya           Selesai     Sudah      DO
# 67                  Ya           Selesai     Sudah      DO
# 68               Tidak             Tidak     Tidak      DO
# 69                  Ya           Selesai     Sudah  NON DO
# 70                  Ya           Selesai     Sudah  NON DO
# 71                  Ya           Selesai     Sudah  NON DO
# 72                  Ya            Proses    Proses  NON DO
# 73                  Ya            Proses    Proses  NON DO
# 74                  Ya           Selesai     Sudah  NON DO
# 75                  Ya            Proses    Proses  NON DO
# 76                  Ya           Selesai     Sudah  NON DO
# 77                  Ya            Proses    Proses  NON DO
# 78               Tidak             Tidak     Tidak      DO
# 79               Tidak             Tidak     Tidak      DO
# 80               Tidak             Tidak     Tidak      DO
# 81                  Ya           Selesai     Sudah  NON DO
# 82               Tidak             Tidak     Tidak      DO
# 83                  Ya            Proses    Proses  NON DO
# 84               Tidak             Tidak     Tidak      DO
# 85               Tidak             Tidak     Tidak      DO
# 86                  Ya            Proses    Proses  NON DO
# 87               Tidak             Tidak     Tidak      DO
# 88               Tidak             Tidak     Tidak      DO
# 89                  Ya           Selesai     Sudah  NON DO
# 90                  Ya            Proses    Proses  NON DO
# 91                  Ya            Proses    Proses  NON DO
# 92                  Ya            Proses    Proses  NON DO
# 93                  Ya             Tidak     Tidak  NON DO
# 94                  Ya            Proses    Proses  NON DO
# 95                  Ya            Proses    Proses  NON DO
# 96                  Ya           Selesai     Sudah  NON DO
# 97                  Ya            Proses    Proses  NON DO
# 98                  Ya           Selesai     Sudah  NON DO
# 99                  Ya           Selesai     Sudah  NON DO
# 100                 Ya            Proses    Proses  NON DO
# 101                 Ya            Proses    Proses  NON DO
# 102                 Ya            Proses    Proses  NON DO
# 103                 Ya            Proses    Proses  NON DO
# 104                 Ya            Proses    Proses  NON DO
# 105                 Ya            Proses    Proses  NON DO
# 106                 Ya            Proses    Proses  NON DO
# 107              Tidak             Tidak     Tidak      DO
# 108                 Ya            Proses    Proses  NON DO
# 109              Tidak             Tidak     Tidak      DO

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()

# %%
le.fit(data['Usia'])
le.classes_
# Out:
# array(['Menengah', 'Muda', 'Tua'], dtype=object)

# %%
le = preprocessing.LabelEncoder()
data['Jenis Kelamin'] = le.fit_transform(data['Jenis Kelamin'].values)
data['Status Bekerja'] = le.fit_transform(data['Status Bekerja'].values)
data['Status Berkeluarga'] = le.fit_transform(data['Status Berkeluarga'].values)
data['Usia'] = le.fit_transform(data['Usia'].values)
data['Ujian Komprehensif'] = le.fit_transform(data['Ujian Komprehensif'].values)
data['Progres Disertasi'] = le.fit_transform(data['Progres Disertasi'].values)
data['Publikasi'] = le.fit_transform(data['Publikasi'].values)
data['Class'] = le.fit_transform(data['Class'].values)

# %%
print(data.info())
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Jenis Kelamin       110 non-null    int32
#  1   Status Bekerja      110 non-null    int32
#  2   Status Berkeluarga  110 non-null    int32
#  3   Usia                110 non-null    int32
#  4   IP Semester 3       110 non-null    float64
#  5   Ujian Komprehensif  110 non-null    int32
#  6   Progres Disertasi   110 non-null    int32
#  7   Publikasi           110 non-null    int32
#  8   Class               110 non-null    int32
# dtypes: float64(1), int32(8)
# memory usage: 4.4 KB
# None
#    Jenis Kelamin  Status Bekerja  Status Berkeluarga  Usia  IP Semester 3  \
# 0              1               0                   1     2           3.43
# 1              0               0                   1     0           3.75
# 2              0               0                   1     0           3.58
# 3              0               0                   1     2           3.40
# 4              0               0                   1     2           4.00
#
#    Ujian Komprehensif  Progres Disertasi  Publikasi  Class
# 0                   0                  2          2      0
# 1                   1                  1          1      1
# 2                   1                  2          2      0
# 3                   1                  2          2      0
# 4                   1                  2          2      0

# %%
X=data[['Jenis Kelamin','Status Bekerja','Status Berkeluarga','Usia','Ujian Komprehensif','Progres Disertasi','IP Semester 3','Publikasi']]
Y=data['Class']

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import svm
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2, random_state = 5)
print ("Data Training:", len(X_train))
print ("Data Testing:", len(X_test))
# Out:
# Data Training: 88
# Data Testing: 22

# %%
clf = svm.SVC(kernel='rbf')
scores = cross_val_score(clf, X_train, y_train, cv=10)
clf.fit(X_train, y_train)
pred = clf.predict(X_test)
scores
# Out:
# array([1.        , 1.        , 0.88888889, 0.77777778, 1.        ,
#        1.        , 1.        , 1.        , 0.875     , 1.        ])

# %%
y_pred = clf.predict(X_test)
print('Accuracy of SVM classifier on test set: {:.2f}'.
format(clf.score(X_test, y_test)))
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
print(classification_report(y_test, y_pred))
# Out:
# Accuracy of SVM classifier on test set: 0.91
# [[ 6  2]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.75      0.86         8
#            1       0.88      1.00      0.93        14
#
#     accuracy                           0.91        22
#    macro avg       0.94      0.88      0.90        22
# weighted avg       0.92      0.91      0.91        22
